# %%
import pandas as pd
import os

print("Working directory:", os.getcwd())

file_path = "C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data"

df = pd.read_excel(file_path)

df.head()
# Out:
#   Cell In[9], line 6
#     file_path = "C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data"
#                                                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
print("Current Directory:", os.getcwd())
print("Files inside /data folder:", os.listdir("../data"))
# Out:
# Current Directory: C:\Users\sharan
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 import os
#       2 print("Current Directory:", os.getcwd())
# ----> 3 print("Files inside /data folder:", os.listdir("../data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sharan

# %%
os.listdir()
# Out:
# ['.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'data_analysis.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TM.blf',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Videos']

# %%
import os
print(os.getcwd())
os.listdir()
# Out:
# C:\Users\sharan
# ['.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'data_analysis.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TM.blf',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Videos']

# %%
import os
print(os.getcwd())
os.listdir()
# Out:
# C:\Users\sharan
# ['.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'data_analysis.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TM.blf',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{032f02cf-4676-11ef-8287-8c47be171a1b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Videos']

# %%
import pandas as pd

file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\Karnataka_mgnrega_FY2023_24.xlsx"

df = pd.read_excel(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 import pandas as pd
#       3 file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\Karnataka_mgnrega_FY2023_24.xlsx"
# ----> 5 df = pd.read_excel(file_path)
#       6 df.head()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
import pandas as pd

file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\karnataka_mgnrega_data.xlsx"

df = pd.read_excel(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 5
#       1 import pandas as pd
#       3 file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\karnataka_mgnrega_data.xlsx"
# ----> 5 df = pd.read_excel(file_path)
#       6 df.head()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
import os

data_folder = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data"
print(os.listdir(data_folder))
# Out:
# ['Karnataka_mgnrega_FY2023_24.xlsx.xlsx']

# %%
import os

data_folder = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data"
print(os.listdir(data_folder))
# Out:
# ['Karnataka_mgnrega_FY2023_24.xlsx']

# %%
import pandas as pd

file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\Karnataka_mgnrega_FY2023_24.xlsx"

df = pd.read_excel(file_path)
df.head()
# Out:
#     fin_year month  state_code state_name  district_code district_name  \
# 0  2023-2024   Oct          15  KARNATAKA           1506         BIDAR
# 1  2023-2024   Oct          15  KARNATAKA           1512    DAVANAGERE
# 2  2023-2024   Oct          15  KARNATAKA           1518        KODAGU
# 3  2023-2024   Oct          15  KARNATAKA           1520        KOPPAL
# 4  2023-2024   Oct          15  KARNATAKA           1530        Yadgir
#
#    Approved_Labour_Budget  Average_Wage_rate_per_day_per_person  \
# 0                 3718182                            301.960117
# 1                 2445015                            303.854850
# 2                  349294                            299.625644
# 3                 7829222                            286.004306
# 4                 3492803                            295.596929
#
#    Average_days_of_employment_provided_per_Household  \
# 0                                                 36
# ...

# %%
xls = pd.ExcelFile(file_path)
xls.sheet_names
# Out:
# ['ee03643a-ee4c-48c2-ac30-9f2ff26']

# %%
import pandas as pd

file_path = r"C:\Users\sharan\OneDrive\Desktop\MGNREGA-Karnataka-Analytics\data\Karnataka_mgnrega_FY2023_24.xlsx"

df = pd.read_excel(file_path)
df.head()
# Out:
#     fin_year month  state_code state_name  district_code district_name  \
# 0  2023-2024   Oct          15  KARNATAKA           1506         BIDAR
# 1  2023-2024   Oct          15  KARNATAKA           1512    DAVANAGERE
# 2  2023-2024   Oct          15  KARNATAKA           1518        KODAGU
# 3  2023-2024   Oct          15  KARNATAKA           1520        KOPPAL
# 4  2023-2024   Oct          15  KARNATAKA           1530        Yadgir
#
#    Approved_Labour_Budget  Average_Wage_rate_per_day_per_person  \
# 0                 3718182                            301.960117
# 1                 2445015                            303.854850
# 2                  349294                            299.625644
# 3                 7829222                            286.004306
# 4                 3492803                            295.596929
#
#    Average_days_of_employment_provided_per_Household  \
# 0                                                 36
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 36 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   fin_year                                               372 non-null    object
#  1   month                                                  372 non-null    object
#  2   state_code                                             372 non-null    int64
#  3   state_name                                             372 non-null    object
#  4   district_code                                          372 non-null    int64
#  5   district_name                                          372 non-null    object
#  6   Approved_Labour_Budget                                 372 non-null    int64
#  7   Average_Wage_rate_per_day_per_person                   372 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['fin_year', 'month', 'state_code', 'state_name', 'district_code',
#        'district_name', 'Approved_Labour_Budget',
#        'Average_Wage_rate_per_day_per_person',
#        'Average_days_of_employment_provided_per_Household',
#        'Differently_abled_persons_worked', 'Material_and_skilled_Wages',
#        'Number_of_Completed_Works', 'Number_of_GPs_with_NIL_exp',
#        'Number_of_Ongoing_Works', 'Persondays_of_Central_Liability_so_far',
#        'SC_persondays', 'SC_workers_against_active_workers', 'ST_persondays',
#        'ST_workers_against_active_workers', 'Total_Adm_Expenditure',
#        'Total_Exp', 'Total_Households_Worked', 'Total_Individuals_Worked',
#        'Total_No_of_Active_Job_Cards', 'Total_No_of_Active_Workers',
#        'Total_No_of_HHs_completed_100_Days_of_Wage_Employment',
#        'Total_No_of_JobCards_issued', 'Total_No_of_Workers',
#        'Total_No_of_Works_Takenup', 'Wages', 'Women_Persondays',
#        'percent_of_Category_B_Works',
# ...

# %%
df.head()
# Out:
#     fin_year month  state_code state_name  district_code district_name  \
# 0  2023-2024   Oct          15  KARNATAKA           1506         BIDAR
# 1  2023-2024   Oct          15  KARNATAKA           1512    DAVANAGERE
# 2  2023-2024   Oct          15  KARNATAKA           1518        KODAGU
# 3  2023-2024   Oct          15  KARNATAKA           1520        KOPPAL
# 4  2023-2024   Oct          15  KARNATAKA           1530        Yadgir
#
#    Approved_Labour_Budget  Average_Wage_rate_per_day_per_person  \
# 0                 3718182                            301.960117
# 1                 2445015                            303.854850
# 2                  349294                            299.625644
# 3                 7829222                            286.004306
# 4                 3492803                            295.596929
#
#    Average_days_of_employment_provided_per_Household  \
# 0                                                 36
# ...

# %%
df['District'].nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'District'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# fin_year
# month
# state_code
# state_name
# district_code
# district_name
# Approved_Labour_Budget
# Average_Wage_rate_per_day_per_person
# Average_days_of_employment_provided_per_Household
# Differently_abled_persons_worked
# Material_and_skilled_Wages
# Number_of_Completed_Works
# Number_of_GPs_with_NIL_exp
# Number_of_Ongoing_Works
# Persondays_of_Central_Liability_so_far
# SC_persondays
# SC_workers_against_active_workers
# ST_persondays
# ST_workers_against_active_workers
# Total_Adm_Expenditure
# Total_Exp
# Total_Households_Worked
# Total_Individuals_Worked
# Total_No_of_Active_Job_Cards
# Total_No_of_Active_Workers
# Total_No_of_HHs_completed_100_Days_of_Wage_Employment
# Total_No_of_JobCards_issued
# Total_No_of_Workers
# Total_No_of_Works_Takenup
# Wages
# Women_Persondays
# percent_of_Category_B_Works
# percent_of_Expenditure_on_Agriculture_Allied_Works
# percent_of_NRM_Expenditure
# percentage_payments_gererated_within_15_days
# Remarks

# %%
df['district_name'].nunique()
# Out:
# 31

# %%
df['district_name'].unique()
# Out:
# array(['BIDAR', 'DAVANAGERE', 'KODAGU', 'KOPPAL', 'Yadgir', 'KALABURAGI',
#        'CHIKKABALLAPURA', 'BALLARI', 'VIJAYPURA', 'DHARWAR', 'KOLAR',
#        'CHIKKAMAGALURU', 'HAVERI', 'MANDYA', 'RAICHUR', 'TUMAKURU',
#        'BENGALURU', 'BELAGAVI', 'BENGALURU RURAL', 'CHAMARAJA NAGARA',
#        'GADAG', 'HASSAN', 'SHIVAMOGGA', 'VIJAYANAGARA', 'UDUPI', 'MYSURU',
#        'UTTARA KANNADA', 'RAMANAGARA', 'BAGALKOTE', 'CHITRADURGA',
#        'DAKSHINA KANNADA'], dtype=object)

# %%
df.isna().sum()
# Out:
# fin_year                                                   0
# month                                                      0
# state_code                                                 0
# state_name                                                 0
# district_code                                              0
# district_name                                              0
# Approved_Labour_Budget                                     0
# Average_Wage_rate_per_day_per_person                       0
# Average_days_of_employment_provided_per_Household          0
# Differently_abled_persons_worked                           0
# Material_and_skilled_Wages                                 0
# Number_of_Completed_Works                                  0
# Number_of_GPs_with_NIL_exp                                 0
# Number_of_Ongoing_Works                                    0
# Persondays_of_Central_Liability_so_far                     0
# ...

# %%
# Show column names
print(df.columns)

# Rename columns for easy use
df.rename(columns={
    'district_name': 'District',
    'state_name': 'State'
}, inplace=True)

# Check missing values
df.isnull().sum()

# Remove rows where District is missing
df = df[df['District'].notna()]

# Convert Month to numeric if required
# (Some datasets have month names)
df['month'] = df['month'].astype(str)

print("✅ Data Cleaning Completed")
# Out:
# Index(['fin_year', 'month', 'state_code', 'state_name', 'district_code',
#        'district_name', 'Approved_Labour_Budget',
#        'Average_Wage_rate_per_day_per_person',
#        'Average_days_of_employment_provided_per_Household',
#        'Differently_abled_persons_worked', 'Material_and_skilled_Wages',
#        'Number_of_Completed_Works', 'Number_of_GPs_with_NIL_exp',
#        'Number_of_Ongoing_Works', 'Persondays_of_Central_Liability_so_far',
#        'SC_persondays', 'SC_workers_against_active_workers', 'ST_persondays',
#        'ST_workers_against_active_workers', 'Total_Adm_Expenditure',
#        'Total_Exp', 'Total_Households_Worked', 'Total_Individuals_Worked',
#        'Total_No_of_Active_Job_Cards', 'Total_No_of_Active_Workers',
#        'Total_No_of_HHs_completed_100_Days_of_Wage_Employment',
#        'Total_No_of_JobCards_issued', 'Total_No_of_Workers',
#        'Total_No_of_Works_Takenup', 'Wages', 'Women_Persondays',
#        'percent_of_Category_B_Works',
# ...
